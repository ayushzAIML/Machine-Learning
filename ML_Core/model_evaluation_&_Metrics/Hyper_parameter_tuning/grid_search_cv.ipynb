# %%
import numpy as np
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X = df.drop('species',axis=1)
y = df['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier(n_neighbors=10,metric='minkowski',weights='distance',algorithm='auto')
model_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10, weights='distance')

# %%
model_knn.score(X_test,y_test)
# Out:
# 0.98

# %%
from sklearn.svm import SVC
model_svm = SVC(C=1,kernel='linear',gamma='auto')

# %%
model_svm.fit(X_train,y_train)
# Out:
# SVC(C=1, gamma='auto', kernel='linear')

# %%
model_svm.score(X_test,y_test)
# Out:
# 1.0

# %%
# now lets use grid search cv

# %%
from sklearn.model_selection import GridSearchCV
classifier = GridSearchCV((model_svm), param_grid={
    'C':[1,10,20,30],
    'kernel':['linear','rbf']

},cv=5,return_train_score=True)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=1, gamma='auto', kernel='linear'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['linear', 'rbf']},
#              return_train_score=True)

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00166159, 0.00118866, 0.00110488, 0.00114036, 0.00108352,
#         0.00129023, 0.00115538, 0.00114098]),
#  'std_fit_time': array([5.12268789e-04, 4.01129180e-05, 2.29850349e-05, 7.51226639e-06,
#         2.38545384e-05, 1.93621347e-04, 5.40002029e-05, 6.14472721e-06]),
#  'mean_score_time': array([0.0010283 , 0.00086293, 0.00083251, 0.00084043, 0.00082231,
#         0.00091619, 0.00089884, 0.00084686]),
#  'std_score_time': array([2.29649597e-04, 1.56571135e-05, 4.72381758e-06, 1.02658511e-05,
#         1.11533017e-05, 6.76511447e-05, 1.01939822e-04, 1.41653545e-05]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'linear', 'rbf', 'linear', 'rbf',
#                     'linear', 'rbf'],
#               mask=[False, False, False, False, False, False, False, False],
# ...

# %%
results = pd.DataFrame(classifier.cv_results_)
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.980000
# 1        1          rbf         0.980000
# 2       10       linear         0.973333
# 3       10          rbf         0.980000
# 4       20       linear         0.966667
# 5       20          rbf         0.966667
# 6       30       linear         0.960000
# 7       30          rbf         0.960000

# %%
classifier_knn = GridSearchCV((model_knn), param_grid={
    'n_neighbors':[3,5,7,9,10,15,20],
    'weights':['uniform','distance'],
    'algorithm':['auto','ball_tree','kd_tree','brute'],
    'metric':['minkowski','euclidean','manhattan']
},cv = 5,return_train_score=False)
classifier_knn.fit(X,y)
# Out:
# GridSearchCV(cv=5,
#              estimator=KNeighborsClassifier(n_neighbors=10, weights='distance'),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'metric': ['minkowski', 'euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9, 10, 15, 20],
#                          'weights': ['uniform', 'distance']})

# %%
results_k = pd.DataFrame(classifier_knn.cv_results_)
results_k[['param_n_neighbors','param_algorithm','param_metric','param_weights']]
# Out:
#      param_n_neighbors param_algorithm param_metric param_weights
# 0                    3            auto    minkowski       uniform
# 1                    3            auto    minkowski      distance
# 2                    5            auto    minkowski       uniform
# 3                    5            auto    minkowski      distance
# 4                    7            auto    minkowski       uniform
# ..                 ...             ...          ...           ...
# 163                 10           brute    manhattan      distance
# 164                 15           brute    manhattan       uniform
# 165                 15           brute    manhattan      distance
# 166                 20           brute    manhattan       uniform
# 167                 20           brute    manhattan      distance
#
# [168 rows x 4 columns]
